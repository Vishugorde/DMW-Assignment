# %% [raw]
# Data preprocessing

# %%
#import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#IMDB Video Games dataset
df=pd.read_csv('imdb-videogames.csv')
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')

# %%
df.describe()
# Out:
#          Unnamed: 0          year        rating
# count  20803.000000  20536.000000  11600.000000
# mean   10401.000000   2005.568611      7.047526
# std     6005.453161     11.846028      1.235204
# min        0.000000   1952.000000      1.000000
# 25%     5200.500000   1997.000000      6.400000
# 50%    10401.000000   2008.000000      7.200000
# 75%    15601.500000   2016.000000      7.900000
# max    20802.000000   2027.000000      9.700000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20803 entries, 0 to 20802
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   20803 non-null  int64
#  1   name         20803 non-null  object
#  2   url          20803 non-null  object
#  3   year         20536 non-null  float64
#  4   certificate  7903 non-null   object
#  5   rating       11600 non-null  float64
#  6   votes        11600 non-null  object
#  7   plot         20803 non-null  object
#  8   Action       20803 non-null  bool
#  9   Adventure    20803 non-null  bool
#  10  Comedy       20803 non-null  bool
#  11  Crime        20803 non-null  bool
#  12  Family       20803 non-null  bool
#  13  Fantasy      20803 non-null  bool
#  14  Mystery      20803 non-null  bool
#  15  Sci-Fi       20803 non-null  bool
#  16  Thriller     20803 non-null  bool
# dtypes: bool(9), float64(2), int64(1), object(5)
# memory usage: 1.4+ MB

# %%
#displays first five rows of the dataset
df.head()
# Out:
#     id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0  1.0           1043     1          1.8         1  14       0           5
# 1  2.0            841     1          0.5         1   4       1          61
# 2  3.0           1807     1          2.8         0   1       0          27
# 3  4.0           1546     0          0.5         1  18       1          25
# 4  5.0           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0    0.1        193  ...        226      1412  3476    12     7          2
# 1    0.8        191  ...        746       857  3895     6     0          7
# 2    0.9        186  ...       1270      1366  2396    17    10         10
# 3    0.5         96  ...        295      1752  3893    10     0          7
# 4    0.5        108  ...        749       810  1773    15     8          7
#
#    three_g  touch_screen  wifi  price_range
# ...

# %%
#cleaning

df.isnull().sum()
# Out:
# id               2000
# battery_power       0
# blue                0
# clock_speed         0
# dual_sim            0
# fc                  0
# four_g              0
# int_memory          0
# m_dep               0
# mobile_wt           0
# n_cores             0
# pc                  0
# px_height           0
# px_width            0
# ram                 0
# sc_h                0
# sc_w                0
# talk_time           0
# three_g             0
# touch_screen        0
# wifi                0
# price_range      1000
# dtype: int64

# %%
#to replace missing values
data1=df.fillna(method="ffill")

# %%
#To check whether the valuies are replaced
data1.isnull().sum()
# Out:
# Unnamed: 0     0
# name           0
# url            0
# year           0
# certificate    0
# rating         0
# votes          0
# plot           0
# Action         0
# Adventure      0
# Comedy         0
# Crime          0
# Family         0
# Fantasy        0
# Mystery        0
# Sci-Fi         0
# Thriller       0
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0                        name  \
# 0           0                  Spider-Man
# 1           1      Red Dead Redemption II
# 2           2          Grand Theft Auto V
# 3           3                  God of War
# 4           4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# ...

# %%
#reduction

cols=['url','plot']
df = df.drop(cols, axis=1)

# %%
#To checkif the columns are dropped
df.head()
# Out:
#    Unnamed: 0                        name    year certificate  rating   votes  \
# 0           0                  Spider-Man  2018.0           T     9.2  20,759
# 1           1      Red Dead Redemption II  2018.0           M     9.7  35,703
# 2           2          Grand Theft Auto V  2013.0           M     9.5  59,986
# 3           3                  God of War  2018.0           M     9.6  26,118
# 4           4  Uncharted 4: A Thief's End  2016.0           T     9.5  28,722
#
#    Action  Adventure  Comedy  Crime  Family  Fantasy  Mystery  Sci-Fi  \
# 0    True       True   False  False   False     True    False   False
# 1    True       True   False   True   False    False    False   False
# 2    True      False   False   True   False    False    False   False
# 3    True       True   False  False   False    False    False   False
# 4    True       True   False  False   False    False    False   False
#
#    Thriller
# 0     False
# 1     False
# 2     False
# 3     False
# ...

# %%
#Transformation

data1.head()
# Out:
#    Unnamed: 0                        name  \
# 0           0                  Spider-Man
# 1           1      Red Dead Redemption II
# 2           2          Grand Theft Auto V
# 3           3                  God of War
# 4           4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# ...

# %%
dummy=pd.get_dummies(data1['Action'])

# %%
dummy
# Out:
#        False  True
# 0          0     1
# 1          0     1
# 2          0     1
# 3          0     1
# 4          0     1
# ...      ...   ...
# 20798      1     0
# 20799      1     0
# 20800      1     0
# 20801      1     0
# 20802      1     0
#
# [20803 rows x 2 columns]

# %%
data2=pd.concat((data1,dummy),axis=1)

# %%
data2=data2.drop(['Action'],axis=1)

# %%
data2.head()
# Out:
#    Unnamed: 0                        name  \
# 0           0                  Spider-Man
# 1           1      Red Dead Redemption II
# 2           2          Grand Theft Auto V
# 3           3                  God of War
# 4           4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...
# ...

# %%
# To plot histogram
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'year'}>],
#        [<AxesSubplot:title={'center':'rating'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
test
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
#integration 
#merging two datasets
df=pd.concat([test,train])

# %%
df
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0     1.0           1043     1          1.8         1  14       0           5
# 1     2.0            841     1          0.5         1   4       1          61
# 2     3.0           1807     1          2.8         0   1       0          27
# 3     4.0           1546     0          0.5         1  18       1          25
# 4     5.0           1434     0          1.4         0  11       1          49
# ...   ...            ...   ...          ...       ...  ..     ...         ...
# 1995  NaN            794     1          0.5         1   0       1           2
# 1996  NaN           1965     1          2.6         1   0       0          39
# 1997  NaN           1911     0          0.9         1   1       1          36
# 1998  NaN           1512     0          0.9         0   4       1          46
# 1999  NaN            510     1          2.0         1   5       1          45
#
# ...
